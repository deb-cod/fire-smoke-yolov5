# %%
import requests
import time

base_url = ""

my_file = open("file-path", 'rb')

parameters = {
    "chat_id" : "",
    "caption" : "message"
}


files = {
    "photo" : my_file
}

resp = requests.get(base_url, data = parameters, files=files)
